# %%
import os
import ipyplot

from RanDepict import RandomDepictor, RandomMarkushStructureCreator
import RanDepict
RanDepict.__version__

os.environ["JAVA_HOME"] = "/home/jovyan/envs/java/jdk1.8.0_421"

# %% [markdown]
# ## Depict chemical structures with CDK, RDKit, Indigo or PIKAChU
#
# After calling an instance of RandomDepictor, depictions with randomly chosen parameters are created by calling the functions `cdk_depict`, `rdkit_depict`, `indigo_depict` and `pikachu_depict`.
#
#
# The SMILES or mol_block string needs to be given.
#
# Each of these functions returns an np.array which represents an RGB image of the chemical structure.

# %%
smiles = "CN1C=NC2=C1C(=O)N(C(=O)N2C)CC(=O)O"
depiction_img_shape = (100, 100)

# random_depictor can be called with a seed for reproducible results (defaults to 42)
with RandomDepictor(seed = 42) as depictor:
    # CDK depictions
    cdk_images = []
    for _ in range(3):
        cdk_images.append(depictor.cdk_depict(smiles=smiles, shape=depiction_img_shape))
    print("_________________CDK depictions_________________")
    ipyplot.plot_images(cdk_images, max_images=10, img_width=100)
    
    # RDKit Depictions
    rdkit_images = []
    for _ in range(3):
        rdkit_images.append(depictor.rdkit_depict(smiles, depiction_img_shape))
    print("_________________RDKit depictions_________________")
    ipyplot.plot_images(rdkit_images, max_images=10, img_width=100)
    
    # Indigo Depictions
    indigo_images = []
    for _ in range(3):
        indigo_images.append(depictor.indigo_depict(smiles, depiction_img_shape))
    print("_________________Indigo depictions_________________")
    indigo_images = list([img for img in indigo_images if img is not None])
    ipyplot.plot_images(indigo_images, max_images=10, img_width=100)
    
    # PIKAChU Depictions
    pikachu_images = []
    for _ in range(3):
        pikachu_images.append(depictor.pikachu_depict(smiles, depiction_img_shape))
    print("_________________PIKAChU depictions_________________")
    ipyplot.plot_images(pikachu_images, max_images=10, img_width=100)
# Out:
# _________________CDK depictions_________________
#     <style>
#         #ipyplot-html-viewer-toggle-meFzurAqNrhqpGysX5XqmW {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-meFzurAqNrhqpGysX5XqmW {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-meFzurAqNrhqpGysX5XqmW {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-meFzurAqNrhqpGysX5XqmW:checked ~ #ipyplot-html-viewer-textarea-meFzurAqNrhqpGysX5XqmW {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-meFzurAqNrhqpGysX5XqmW:checked + #ipyplot-html-viewer-label-meFzurAqNrhqpGysX5XqmW:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-meFzurAqNrhqpGysX5XqmW">
#         <label id="ipyplot-html-viewer-label-meFzurAqNrhqpGysX5XqmW" for="ipyplot-html-viewer-toggle-meFzurAqNrhqpGysX5XqmW">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-meFzurAqNrhqpGysX5XqmW" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-CqVcXhLvmzu4ZmhD9de58t {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-CqVcXhLvmzu4ZmhD9de58t {
#             width: 100px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-CqVcXhLvmzu4ZmhD9de58t {
#             width: 100px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-CqVcXhLvmzu4ZmhD9de58t span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-CqVcXhLvmzu4ZmhD9de58t span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-CqVcXhLvmzu4ZmhD9de58t img {
#             width: 100px;
#         }
#
#         div.ipyplot-content-div-CqVcXhLvmzu4ZmhD9de58t span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-CqVcXhLvmzu4ZmhD9de58t span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-CqVcXhLvmzu4ZmhD9de58t]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-CqVcXhLvmzu4ZmhD9de58t]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-CqVcXhLvmzu4ZmhD9de58t]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-CqVcXhLvmzu4ZmhD9de58t">
#     <div class="ipyplot-placeholder-div-CqVcXhLvmzu4ZmhD9de58t">
#         <div id="ipyplot-content-div-CqVcXhLvmzu4ZmhD9de58t-kbiugfq5c7cjaCpsQ4KzAF" class="ipyplot-content-div-CqVcXhLvmzu4ZmhD9de58t">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-CqVcXhLvmzu4ZmhD9de58t-kbiugfq5c7cjaCpsQ4KzAF">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-CqVcXhLvmzu4ZmhD9de58t">
#         <div id="ipyplot-content-div-CqVcXhLvmzu4ZmhD9de58t-FkawdRnopfhMiJaSbDGQVb" class="ipyplot-content-div-CqVcXhLvmzu4ZmhD9de58t">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-CqVcXhLvmzu4ZmhD9de58t-FkawdRnopfhMiJaSbDGQVb">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-CqVcXhLvmzu4ZmhD9de58t">
#         <div id="ipyplot-content-div-CqVcXhLvmzu4ZmhD9de58t-49MFXY2PJ3jhiCmTrJDsD8" class="ipyplot-content-div-CqVcXhLvmzu4ZmhD9de58t">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-CqVcXhLvmzu4ZmhD9de58t-49MFXY2PJ3jhiCmTrJDsD8">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-CqVcXhLvmzu4ZmhD9de58t {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-CqVcXhLvmzu4ZmhD9de58t {
#             width: 100px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-CqVcXhLvmzu4ZmhD9de58t {
#             width: 100px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-CqVcXhLvmzu4ZmhD9de58t span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-CqVcXhLvmzu4ZmhD9de58t span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-CqVcXhLvmzu4ZmhD9de58t img {
#             width: 100px;
#         }
#
#         div.ipyplot-content-div-CqVcXhLvmzu4ZmhD9de58t span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-CqVcXhLvmzu4ZmhD9de58t span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-CqVcXhLvmzu4ZmhD9de58t]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-CqVcXhLvmzu4ZmhD9de58t]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-CqVcXhLvmzu4ZmhD9de58t]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-CqVcXhLvmzu4ZmhD9de58t">
#     <div class="ipyplot-placeholder-div-CqVcXhLvmzu4ZmhD9de58t">
#         <div id="ipyplot-content-div-CqVcXhLvmzu4ZmhD9de58t-kbiugfq5c7cjaCpsQ4KzAF" class="ipyplot-content-div-CqVcXhLvmzu4ZmhD9de58t">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-CqVcXhLvmzu4ZmhD9de58t-kbiugfq5c7cjaCpsQ4KzAF">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-CqVcXhLvmzu4ZmhD9de58t">
#         <div id="ipyplot-content-div-CqVcXhLvmzu4ZmhD9de58t-FkawdRnopfhMiJaSbDGQVb" class="ipyplot-content-div-CqVcXhLvmzu4ZmhD9de58t">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-CqVcXhLvmzu4ZmhD9de58t-FkawdRnopfhMiJaSbDGQVb">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-CqVcXhLvmzu4ZmhD9de58t">
#         <div id="ipyplot-content-div-CqVcXhLvmzu4ZmhD9de58t-49MFXY2PJ3jhiCmTrJDsD8" class="ipyplot-content-div-CqVcXhLvmzu4ZmhD9de58t">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-CqVcXhLvmzu4ZmhD9de58t-49MFXY2PJ3jhiCmTrJDsD8">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
# _________________RDKit depictions_________________
#     <style>
#         #ipyplot-html-viewer-toggle-JAub7ikCgmNxupumrBp7mW {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-JAub7ikCgmNxupumrBp7mW {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-JAub7ikCgmNxupumrBp7mW {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-JAub7ikCgmNxupumrBp7mW:checked ~ #ipyplot-html-viewer-textarea-JAub7ikCgmNxupumrBp7mW {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-JAub7ikCgmNxupumrBp7mW:checked + #ipyplot-html-viewer-label-JAub7ikCgmNxupumrBp7mW:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-JAub7ikCgmNxupumrBp7mW">
#         <label id="ipyplot-html-viewer-label-JAub7ikCgmNxupumrBp7mW" for="ipyplot-html-viewer-toggle-JAub7ikCgmNxupumrBp7mW">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-JAub7ikCgmNxupumrBp7mW" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-2aqMBtMM6LrUUWDx4WaBWQ {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-2aqMBtMM6LrUUWDx4WaBWQ {
#             width: 100px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-2aqMBtMM6LrUUWDx4WaBWQ {
#             width: 100px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-2aqMBtMM6LrUUWDx4WaBWQ span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-2aqMBtMM6LrUUWDx4WaBWQ span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-2aqMBtMM6LrUUWDx4WaBWQ img {
#             width: 100px;
#         }
#
#         div.ipyplot-content-div-2aqMBtMM6LrUUWDx4WaBWQ span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-2aqMBtMM6LrUUWDx4WaBWQ span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-2aqMBtMM6LrUUWDx4WaBWQ]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-2aqMBtMM6LrUUWDx4WaBWQ]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-2aqMBtMM6LrUUWDx4WaBWQ]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-2aqMBtMM6LrUUWDx4WaBWQ">
#     <div class="ipyplot-placeholder-div-2aqMBtMM6LrUUWDx4WaBWQ">
#         <div id="ipyplot-content-div-2aqMBtMM6LrUUWDx4WaBWQ-JT7nR99ZSxAfpspH65s9cx" class="ipyplot-content-div-2aqMBtMM6LrUUWDx4WaBWQ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-2aqMBtMM6LrUUWDx4WaBWQ-JT7nR99ZSxAfpspH65s9cx">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-2aqMBtMM6LrUUWDx4WaBWQ">
#         <div id="ipyplot-content-div-2aqMBtMM6LrUUWDx4WaBWQ-7QQseHjuFgwT2ox3KsWE9x" class="ipyplot-content-div-2aqMBtMM6LrUUWDx4WaBWQ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-2aqMBtMM6LrUUWDx4WaBWQ-7QQseHjuFgwT2ox3KsWE9x">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-2aqMBtMM6LrUUWDx4WaBWQ">
#         <div id="ipyplot-content-div-2aqMBtMM6LrUUWDx4WaBWQ-TQCoamppSnKxDKhPkJEBea" class="ipyplot-content-div-2aqMBtMM6LrUUWDx4WaBWQ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-2aqMBtMM6LrUUWDx4WaBWQ-TQCoamppSnKxDKhPkJEBea">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-2aqMBtMM6LrUUWDx4WaBWQ {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-2aqMBtMM6LrUUWDx4WaBWQ {
#             width: 100px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-2aqMBtMM6LrUUWDx4WaBWQ {
#             width: 100px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-2aqMBtMM6LrUUWDx4WaBWQ span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-2aqMBtMM6LrUUWDx4WaBWQ span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-2aqMBtMM6LrUUWDx4WaBWQ img {
#             width: 100px;
#         }
#
#         div.ipyplot-content-div-2aqMBtMM6LrUUWDx4WaBWQ span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-2aqMBtMM6LrUUWDx4WaBWQ span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-2aqMBtMM6LrUUWDx4WaBWQ]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-2aqMBtMM6LrUUWDx4WaBWQ]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-2aqMBtMM6LrUUWDx4WaBWQ]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-2aqMBtMM6LrUUWDx4WaBWQ">
#     <div class="ipyplot-placeholder-div-2aqMBtMM6LrUUWDx4WaBWQ">
#         <div id="ipyplot-content-div-2aqMBtMM6LrUUWDx4WaBWQ-JT7nR99ZSxAfpspH65s9cx" class="ipyplot-content-div-2aqMBtMM6LrUUWDx4WaBWQ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-2aqMBtMM6LrUUWDx4WaBWQ-JT7nR99ZSxAfpspH65s9cx">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-2aqMBtMM6LrUUWDx4WaBWQ">
#         <div id="ipyplot-content-div-2aqMBtMM6LrUUWDx4WaBWQ-7QQseHjuFgwT2ox3KsWE9x" class="ipyplot-content-div-2aqMBtMM6LrUUWDx4WaBWQ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-2aqMBtMM6LrUUWDx4WaBWQ-7QQseHjuFgwT2ox3KsWE9x">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-2aqMBtMM6LrUUWDx4WaBWQ">
#         <div id="ipyplot-content-div-2aqMBtMM6LrUUWDx4WaBWQ-TQCoamppSnKxDKhPkJEBea" class="ipyplot-content-div-2aqMBtMM6LrUUWDx4WaBWQ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-2aqMBtMM6LrUUWDx4WaBWQ-TQCoamppSnKxDKhPkJEBea">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
# ---------------------------------------------------------------------------
# IndigoException                           Traceback (most recent call last)
# Cell In[12], line 23
#      21 indigo_images = []
#      22 for _ in range(3):
# ---> 23     indigo_images.append(depictor.indigo_depict(smiles, depiction_img_shape))
#      24 print("_________________Indigo depictions_________________")
#      25 indigo_images = list([img for img in indigo_images if img is not None])
#
# File ~/envs/DETR/lib/python3.8/site-packages/RanDepict/indigo_functionalities.py:40, in IndigoFunctionalities.indigo_depict(self, smiles, mol_block, shape)
#      25 """
#      26 This function takes a mol block str and an image shape.
#      27 It renders the chemical structures using Indigo with random
#    (...)
#      37     np.array: Chemical structure depiction
#      38 """
#      39 # Instantiate Indigo with random settings and IndigoRenderer
# ---> 40 indigo, renderer = self.get_random_indigo_rendering_settings()
#      41 if not smiles and not mol_block:
#      42     raise ValueError("Either smiles or mol_block must be provided")
#
# File ~/envs/DETR/lib/python3.8/site-packages/RanDepict/indigo_functionalities.py:125, in IndigoFunctionalities.get_random_indigo_rendering_settings(self, shape)
#     121 # Collapse superatoms (default: expand)
#     122 if self.random_choice(
#     123     [True, False], log_attribute="indigo_collapse_superatoms"
#     124 ):
# --> 125     indigo.setOption("render-superatom-mode", "collapse")
#     126 return indigo, renderer
#
# File ~/envs/DETR/lib/python3.8/site-packages/indigo/indigo/indigo.py:166, in Indigo.setOption(self, option, value1, value2, value3)
#     164     else:
#     165         raise IndigoException("bad option")
# --> 166     IndigoLib.checkResult(setOpt(opt, value))
#     167 else:
#     168     raise IndigoException("bad option")
#
# File ~/envs/DETR/lib/python3.8/site-packages/indigo/indigo/indigo_lib.py:1045, in IndigoLib.checkResult(result, exception_class)
#    1043 if result < 0:
#    1044     assert IndigoLib.lib
# -> 1045     raise exception_class(IndigoLib.lib.indigoGetLastError())
#    1046 return result
#
# IndigoException: option manager: Property "render-superatom-mode" not defined

# %% [markdown]
# ## Depict chemical structures with a random toolkit
#
# After calling an instance of RandomDepictor, the function
#
#  - random_depiction(
#        smiles: str,
#        image_shape: Tuple[int,int]
#    )
#
# The SMILES string needs to be given, the image_shape defaults to (299,299).
#
# It returns an np.array which represents an RGB image of the chemical structure.
#
# **Markush structures can be handled by the random_depiction() method. As not all of the used toolkits handle every type of markush structure equally well, we recommend using random_depiction as it filters the potential toolkits used for the depiction based on the input SMILES.**

# %%
smiles = "[R1]N1C=NC2=C1C(=[X])N(C(=O)N2C)[Y]"

with RandomDepictor(2, hand_drawn=False) as depictor:
    smiles = depictor._cdk_add_explicite_hydrogen_to_smiles(smiles)
    random_images = []
    for _ in range(20):
        random_images.append(depictor.random_depiction(smiles, shape=(100,100)))

ipyplot.plot_images(random_images, max_images=20, img_width=100)
# Out:
# ---------------------------------------------------------------------------
# IndigoException                           Traceback (most recent call last)
# Cell In[13], line 7
#       5     random_images = []
#       6     for _ in range(20):
# ----> 7         random_images.append(depictor.random_depiction(smiles, shape=(100,100)))
#       9 ipyplot.plot_images(random_images, max_images=20, img_width=100)
#
# File ~/envs/DETR/lib/python3.8/site-packages/RanDepict/randepict.py:209, in RandomDepictor.random_depiction(self, smiles, shape)
#     206 if len(depiction_functions) != 0:
#     207     # Pick random depiction function and call it
#     208     depiction_function = self.random_choice(depiction_functions)
# --> 209     depiction = depiction_function(smiles=smiles, shape=shape)
#     210     if depiction is False or depiction is None:
#     211         depiction_functions.remove(depiction_function)
#
# File ~/envs/DETR/lib/python3.8/site-packages/RanDepict/indigo_functionalities.py:40, in IndigoFunctionalities.indigo_depict(self, smiles, mol_block, shape)
#      25 """
#      26 This function takes a mol block str and an image shape.
#      27 It renders the chemical structures using Indigo with random
#    (...)
#      37     np.array: Chemical structure depiction
#      38 """
#      39 # Instantiate Indigo with random settings and IndigoRenderer
# ---> 40 indigo, renderer = self.get_random_indigo_rendering_settings()
#      41 if not smiles and not mol_block:
#      42     raise ValueError("Either smiles or mol_block must be provided")
#
# File ~/envs/DETR/lib/python3.8/site-packages/RanDepict/indigo_functionalities.py:125, in IndigoFunctionalities.get_random_indigo_rendering_settings(self, shape)
#     121 # Collapse superatoms (default: expand)
#     122 if self.random_choice(
#     123     [True, False], log_attribute="indigo_collapse_superatoms"
#     124 ):
# --> 125     indigo.setOption("render-superatom-mode", "collapse")
#     126 return indigo, renderer
#
# File ~/envs/DETR/lib/python3.8/site-packages/indigo/indigo/indigo.py:166, in Indigo.setOption(self, option, value1, value2, value3)
#     164     else:
#     165         raise IndigoException("bad option")
# --> 166     IndigoLib.checkResult(setOpt(opt, value))
#     167 else:
#     168     raise IndigoException("bad option")
#
# File ~/envs/DETR/lib/python3.8/site-packages/indigo/indigo/indigo_lib.py:1045, in IndigoLib.checkResult(result, exception_class)
#    1043 if result < 0:
#    1044     assert IndigoLib.lib
# -> 1045     raise exception_class(IndigoLib.lib.indigoGetLastError())
#    1046 return result
#
# IndigoException: option manager: Property "render-superatom-mode" not defined

# %% [markdown]
# ## Create random depictions with random augmentations
#
# After calling an instance of RandomDepictor, this instance can simply be called as a function in order to generate a chemical structure depiction using CDK, RDKit, Indigo or PIKAChU (randomly chosen) and apply random augmentations. The augmentations consist of random imgaug augmentations and randomly added chemical ID labels or curved arrows

# %%
smiles = "CN1C=NC2=C1C(=O)N(C(=O)N2C)CC(=O)O"
with RandomDepictor() as depictor:
    random_augmented_images = []
    for _ in range(20):
        random_augmented_images.append(depictor(smiles))
        

ipyplot.plot_images(random_augmented_images, max_images=20, img_width=100)
# Out:
# If you see this message, for some reason JPype cannot find jvm.dll. This indicates that the environment varibale JAVA_HOME is not set properly. You can set it or set it manually in the code (see __init__() of RandomDepictor)
# ---------------------------------------------------------------------------
# BlockingIOError                           Traceback (most recent call last)
# Cell In[4], line 2
#       1 smiles = "CN1C=NC2=C1C(=O)N(C(=O)N2C)CC(=O)O"
# ----> 2 with RandomDepictor() as depictor:
#       3     random_augmented_images = []
#       4     for _ in range(20):
#
# File ~/envs/DETR/lib/python3.8/site-packages/RanDepict/randepict.py:94, in RandomDepictor.__init__(self, seed, hand_drawn, config)
#      92 if not isJVMStarted():
#      93     self.jar_path = self.HERE.joinpath("jar_files/cdk-2.8.jar")
# ---> 94     startJVM(self.jvmPath,
#      95              "-ea",
#      96              "-Djava.class.path=" + str(self.jar_path),
#      97              "-Xmx4096M")
#      99 random.seed(self.seed)
#     101 # Load list of superatoms for label generation
#
# File ~/envs/DETR/lib/python3.8/site-packages/jpype/_core.py:247, in startJVM(jvmpath, classpath, ignoreUnrecognized, convertStrings, interrupt, *jvmargs)
#     245 prior = [locale.getlocale(i) for i in categories]
#     246 # Start the JVM
# --> 247 _jpype.startup(jvmpath, jvmargs + extra_jvm_args,
#     248                ignoreUnrecognized, convertStrings, interrupt)
#     249 # Collect required resources for operation
#     250 initializeResources()
#
# BlockingIOError: [Errno 11] JVM DLL not found: Define/path/or/set/JAVA_HOME/variable/properly

# %% [markdown]
# ## Create random depictions with cxSMILES with coordinates
#
# Simply call the method `random_depiction_with_coordinates` of the `RandomDepictor to` generate a chemical structure depiction using CDK, RDKit, Indigo and apply random augmentations if desired. This function returns the depiction and a cxSMILES string that contains dimensionless coordinates that refer to the atom coordinates in the depiction.

# %%
smiles = "CCCCC"
with RandomDepictor(seed=1) as depictor:
    random_images = []
    for index in range(20):
        if index < 10:
            depiction, cx_smiles = depictor.random_depiction_with_coordinates(smiles,
                                                                              shape=(100,100))
        else:
            depiction, cx_smiles = depictor.random_depiction_with_coordinates(smiles,
                                                                              augment=True,
                                                                              shape=(100,100))
        print(f"{cx_smiles}")
        random_images.append(depiction)
        

ipyplot.plot_images(random_images, max_images=100, img_width=100)
# Out:
# If you see this message, for some reason JPype cannot find jvm.dll. This indicates that the environment varibale JAVA_HOME is not set properly. You can set it or set it manually in the code (see __init__() of RandomDepictor)
# ---------------------------------------------------------------------------
# BlockingIOError                           Traceback (most recent call last)
# Cell In[5], line 2
#       1 smiles = "CCCCC"
# ----> 2 with RandomDepictor(seed=1) as depictor:
#       3     random_images = []
#       4     for index in range(20):
#
# File ~/envs/DETR/lib/python3.8/site-packages/RanDepict/randepict.py:94, in RandomDepictor.__init__(self, seed, hand_drawn, config)
#      92 if not isJVMStarted():
#      93     self.jar_path = self.HERE.joinpath("jar_files/cdk-2.8.jar")
# ---> 94     startJVM(self.jvmPath,
#      95              "-ea",
#      96              "-Djava.class.path=" + str(self.jar_path),
#      97              "-Xmx4096M")
#      99 random.seed(self.seed)
#     101 # Load list of superatoms for label generation
#
# File ~/envs/DETR/lib/python3.8/site-packages/jpype/_core.py:247, in startJVM(jvmpath, classpath, ignoreUnrecognized, convertStrings, interrupt, *jvmargs)
#     245 prior = [locale.getlocale(i) for i in categories]
#     246 # Start the JVM
# --> 247 _jpype.startup(jvmpath, jvmargs + extra_jvm_args,
#     248                ignoreUnrecognized, convertStrings, interrupt)
#     249 # Collect required resources for operation
#     250 initializeResources()
#
# BlockingIOError: [Errno 11] JVM DLL not found: Define/path/or/set/JAVA_HOME/variable/properly

# %% [markdown]
# ## Create random hand-drawn like depictions
#
# After calling an instance of RandomDepictor, this instance can simply be called as a function in order to generate a chemical structure depiction using CDK, RDKit, Indigo or PIKAChU (randomly chosen) and apply random augmentations and random background addition.

# %%
smiles = "CN1C=NC2=C1C(=O)N(C(=O)N2C)CC(=O)O"
with RandomDepictor(hand_drawn=True) as depictor:
    random_augmented_images = []
    for _ in range(20):
        random_augmented_images.append(depictor(smiles))
        

ipyplot.plot_images(random_augmented_images, max_images=20, img_width=100)
# Out:
# ---------------------------------------------------------------------------
# IndigoException                           Traceback (most recent call last)
# Cell In[14], line 5
#       3     random_augmented_images = []
#       4     for _ in range(20):
# ----> 5         random_augmented_images.append(depictor(smiles))
#       8 ipyplot.plot_images(random_augmented_images, max_images=20, img_width=100)
#
# File ~/envs/DETR/lib/python3.8/site-packages/RanDepict/randepict.py:157, in RandomDepictor.__call__(self, smiles, shape, grayscale, hand_drawn)
#     155 hand_drawn = self.hand_drawn
#     156 if hand_drawn:
# --> 157     depiction = self.random_depiction(smiles, shape)
#     158     # TODO is call to hand_drawn_augment missing?
#     159 else:
#     160     depiction = self.random_depiction(smiles, shape)
#
# File ~/envs/DETR/lib/python3.8/site-packages/RanDepict/randepict.py:209, in RandomDepictor.random_depiction(self, smiles, shape)
#     206 if len(depiction_functions) != 0:
#     207     # Pick random depiction function and call it
#     208     depiction_function = self.random_choice(depiction_functions)
# --> 209     depiction = depiction_function(smiles=smiles, shape=shape)
#     210     if depiction is False or depiction is None:
#     211         depiction_functions.remove(depiction_function)
#
# File ~/envs/DETR/lib/python3.8/site-packages/RanDepict/indigo_functionalities.py:40, in IndigoFunctionalities.indigo_depict(self, smiles, mol_block, shape)
#      25 """
#      26 This function takes a mol block str and an image shape.
#      27 It renders the chemical structures using Indigo with random
#    (...)
#      37     np.array: Chemical structure depiction
#      38 """
#      39 # Instantiate Indigo with random settings and IndigoRenderer
# ---> 40 indigo, renderer = self.get_random_indigo_rendering_settings()
#      41 if not smiles and not mol_block:
#      42     raise ValueError("Either smiles or mol_block must be provided")
#
# File ~/envs/DETR/lib/python3.8/site-packages/RanDepict/indigo_functionalities.py:125, in IndigoFunctionalities.get_random_indigo_rendering_settings(self, shape)
#     121 # Collapse superatoms (default: expand)
#     122 if self.random_choice(
#     123     [True, False], log_attribute="indigo_collapse_superatoms"
#     124 ):
# --> 125     indigo.setOption("render-superatom-mode", "collapse")
#     126 return indigo, renderer
#
# File ~/envs/DETR/lib/python3.8/site-packages/indigo/indigo/indigo.py:166, in Indigo.setOption(self, option, value1, value2, value3)
#     164     else:
#     165         raise IndigoException("bad option")
# --> 166     IndigoLib.checkResult(setOpt(opt, value))
#     167 else:
#     168     raise IndigoException("bad option")
#
# File ~/envs/DETR/lib/python3.8/site-packages/indigo/indigo/indigo_lib.py:1045, in IndigoLib.checkResult(result, exception_class)
#    1043 if result < 0:
#    1044     assert IndigoLib.lib
# -> 1045     raise exception_class(IndigoLib.lib.indigoGetLastError())
#    1046 return result
#
# IndigoException: option manager: Property "render-superatom-mode" not defined

# %% [markdown]
# ##

# %% [markdown]
# ## Create and save a batch of images
#
# After calling an instance of RandomDepictor, simply call the method depict_save().
#
# Args:
#
# - smiles_list (List[str]): List of SMILES str
# - images_per_structure (int): Amount of images to create per SMILES str
# - output_dir (str): Output directory
# - augment (bool): Boolean that indicates whether or not to use augmentations
# - ID_list (List[str]): List of IDs (should be as long as smiles_list)
# - shape (Tuple[int, int], optional): image shape. Defaults to (299, 299).
# - processes (int, optional): Number of parallel threads. Defaults to 4.
# - seed (int, optional): Seed for pseudo-random decisions. Defaults to 42.

# %%
# Make sure the output directories exist
if not os.path.exists('not_augmented'):
        os.mkdir('not_augmented')
        
if not os.path.exists('augmented'):
        os.mkdir('augmented')

# Depict and save two batches of images
smiles = "CN1C=NC2=C1C(=O)N(C(=O)N2C)CC(=O)O"
with RandomDepictor(42) as depictor:
    depictor.batch_depict_save([smiles], 20, 'not_augmented', False, ['caffeine'], (299, 299), 5)
    depictor.batch_depict_save([smiles], 20, 'augmented', True, ['caffeine'], (299, 299), 5)
# Out:
# If you see this message, for some reason JPype cannot find jvm.dll. This indicates that the environment varibale JAVA_HOME is not set properly. You can set it or set it manually in the code (see __init__() of RandomDepictor)
# ---------------------------------------------------------------------------
# BlockingIOError                           Traceback (most recent call last)
# Cell In[6], line 10
#       8 # Depict and save two batches of images
#       9 smiles = "CN1C=NC2=C1C(=O)N(C(=O)N2C)CC(=O)O"
# ---> 10 with RandomDepictor(42) as depictor:
#      11     depictor.batch_depict_save([smiles], 20, 'not_augmented', False, ['caffeine'], (299, 299), 5)
#      12     depictor.batch_depict_save([smiles], 20, 'augmented', True, ['caffeine'], (299, 299), 5)
#
# File ~/envs/DETR/lib/python3.8/site-packages/RanDepict/randepict.py:94, in RandomDepictor.__init__(self, seed, hand_drawn, config)
#      92 if not isJVMStarted():
#      93     self.jar_path = self.HERE.joinpath("jar_files/cdk-2.8.jar")
# ---> 94     startJVM(self.jvmPath,
#      95              "-ea",
#      96              "-Djava.class.path=" + str(self.jar_path),
#      97              "-Xmx4096M")
#      99 random.seed(self.seed)
#     101 # Load list of superatoms for label generation
#
# File ~/envs/DETR/lib/python3.8/site-packages/jpype/_core.py:247, in startJVM(jvmpath, classpath, ignoreUnrecognized, convertStrings, interrupt, *jvmargs)
#     245 prior = [locale.getlocale(i) for i in categories]
#     246 # Start the JVM
# --> 247 _jpype.startup(jvmpath, jvmargs + extra_jvm_args,
#     248                ignoreUnrecognized, convertStrings, interrupt)
#     249 # Collect required resources for operation
#     250 initializeResources()
#
# BlockingIOError: [Errno 11] JVM DLL not found: Define/path/or/set/JAVA_HOME/variable/properly

# %%
if not os.path.exists('kohulan'):
    os.mkdir("kohulan")
smiles = "CN1C=NC2=C1C(=O)N(C(=O)N2C)C"
r_smiles = "[R1]N1C=NC2=C1[X](=O)N(C(=O)N2C)[R]"
seed = 233
r_seed = 1
with RandomDepictor(1) as depictor:
    depictor.depict_save(smiles, 1, 'kohulan', False, 'caffeine_299_299', (299, 299), seed=seed)
    depictor.depict_save(smiles, 1, 'kohulan', True, 'caffeine_aug_299_299', (299, 299), seed=seed)
    depictor.depict_save(smiles, 1, 'kohulan', False, 'caffeine_512_512', (512, 512), seed=seed)
    depictor.depict_save(smiles, 1, 'kohulan', True, 'caffeine_aug_512_512', (512, 512), seed=seed)
    depictor.depict_save(r_smiles, 1, 'kohulan', False, 'caffeine_R_299_299', (299, 299), seed=r_seed)
    depictor.depict_save(r_smiles, 1, 'kohulan', True, 'caffeine_R_aug_299_299', (299, 299), seed=r_seed)
    depictor.depict_save(r_smiles, 1, 'kohulan', False, 'caffeine_R_512_512', (512, 512), seed=r_seed)
    depictor.depict_save(r_smiles, 1, 'kohulan', True, 'caffeine_R_aug_512_512', (512, 512), seed=r_seed)
# Out:
# Warning! Rogue electron.
# R1_0
# Warning! Rogue electron.
# R_13
# Warning! Rogue electron.
# R1_0
# Warning! Rogue electron.
# R_13
# Warning! Rogue electron.
# R1_0
# Warning! Rogue electron.
# R_13
# Warning! Rogue electron.
# R1_0
# Warning! Rogue electron.
# R_13
# Warning! Rogue electron.
# R1_0
# Warning! Rogue electron.
# R_13
# Warning! Rogue electron.
# R1_0
# Warning! Rogue electron.
# R_13
# Warning! Rogue electron.
# R1_0
# Warning! Rogue electron.
# R_13
# Warning! Rogue electron.
# R1_0
# Warning! Rogue electron.
# R_13

# %% [markdown]
# ## Create a batch of images while ensuring diversity using feature fingerprints
#
#
# After calling an instance of RandomDepictor, simply call the method batch_depict_with_fingerprints().
#
# Args:
#
# - smiles_list: List[str]
# - images_per_structure: int
# - indigo_proportion: float = 0.15
# - rdkit_proportion: float = 0.25
# - pikachu_proportion: float = 0.25
# - cdk_proportion: float = 0.35
# - aug_proportion: float = 0.5
# - shape: Tuple[int, int] = (299, 299)
# - processes: int = 4
# - seed: int = 42
#
# * Note: Have a look at examples/generate_depiction_grids_with_fingerprints.py to see how this function was used to generate the grid figures from our publication.

# %%
# Depict and save two batches of images
smiles = "CN1C=NC2=C1C(=O)N(C(=O)N2C)C"

with RandomDepictor(42) as depictor:
    fp_depictions = depictor.batch_depict_with_fingerprints([smiles],
                                                         20,
                                                         aug_proportion = 0)
    # TODO: Fix this
    #fp_aug_depictions = depictor.batch_depict_with_fingerprints([smiles],
    #                                                     20,
    #                                                     aug_proportion = 1)
ipyplot.plot_images(fp_depictions, max_images=20, img_width=100)
# ipyplot.plot_images(fp_aug_depictions, max_images=20, img_width=100)
# Out:
# No saved fingerprints found. This may take a minute.
# augmentation fingerprints were saved in /home/jovyan/envs/DETR/lib/python3.8/site-packages/RanDepict/assets/augmentation_fingerprints.npz.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 12
#       5     fp_depictions = depictor.batch_depict_with_fingerprints([smiles],
#       6                                                          20,
#       7                                                          aug_proportion = 0)
#       8     # TODO: Fix this
#       9     #fp_aug_depictions = depictor.batch_depict_with_fingerprints([smiles],
#      10     #                                                     20,
#      11     #                                                     aug_proportion = 1)
# ---> 12 ipyplot.plot_images(fp_depictions, max_images=20, img_width=100)
#      13 # ipyplot.plot_images(fp_aug_depictions, max_images=20, img_width=100)
#
# File ~/envs/DETR/lib/python3.8/site-packages/ipyplot/_plotting.py:135, in plot_images(images, labels, custom_texts, max_images, img_width, zoom_scale, show_url, force_b64)
#      88 def plot_images(
#      89         images: Sequence[object],
#      90         labels: Sequence[str or int] = None,
#    (...)
#      95         show_url: bool = True,
#      96         force_b64: bool = False):
#      97     """
#      98     Simply displays images provided in `images` param in grid-like layout.
#      99     Check optional params for max number of images to plot, labels and custom texts to add to each image, image width and other options.
#    (...)
#     132         Defaults to False.
#     133     """  # NOQA E501
# --> 135     images = _seq2arr(images)
#     137     if labels is None:
#     138         labels = list(range(0, len(images)))
#
# File ~/envs/DETR/lib/python3.8/site-packages/ipyplot/_utils.py:97, in _seq2arr(seq)
#      95     return np.asarray(seq, dtype=type(seq[0]))
#      96 else:
# ---> 97     return np.asarray(seq)
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (20,) + inhomogeneous part.

# %% [markdown]
# ## Create and save a batch of images while ensuring diversity using feature fingerprints
#
#
# After calling an instance of RandomDepictor, simply call the method batch_depict_save_with_fingerprints().
#
# Args:
#
# - smiles_list: List[str]
# - images_per_structure: int
# - output_dir: str
# - ID_list: List[str]
# - indigo_proportion: float = 0.15
# - rdkit_proportion: float = 0.3
# - cdk_proportion: float = 0.55
# - aug_proportion: float = 0.5
# - shape: Tuple[int, int] = (299, 299)
# - processes: int = 4
# - seed: int = 42
#
#
# *Note: The images that are created here, were used for the animations in the GitHub repository

# %%
# Make sure the output directories exist
if not os.path.exists('not_augmented_fingerprint'):
        os.mkdir('not_augmented_fingerprint')
        
if not os.path.exists('augmented_fingerprint'):
        os.mkdir('augmented_fingerprint')

# Depict and save two batches of images
smiles = "CN1C=NC2=C1C(=O)N(C(=O)N2C)CC(=O)O"
with RandomDepictor(42) as depictor:
    depictor.batch_depict_save_with_fingerprints([smiles], 
                                                 100, 
                                                 'not_augmented_fingerprint',
                                                ['caffeine_{}'.format(n) for n in range(100)],
                                                aug_proportion = 0)
    # TODO: FIX THIS
    #depictor.batch_depict_save_with_fingerprints([smiles], 
    #                                             100, 
    #                                             'augmented_fingerprint',
    #                                            ['caffeine_{}'.format(n) for n in range(100)],
    #                                            aug_proportion = 1)

# %% [markdown]
# ## Artificial generation of SMILES that represent markush structures
#
# Generate markush structures based on list of SMILES strings

# %%
markush_generator = RandomMarkushStructureCreator()
input_smiles = ['CN1C=NC2=C1C(=O)N(C(=O)N2C)C'] * 100
markush_smiles = markush_generator.generate_markush_structure_dataset(input_smiles)
markush_smiles
# Out:
# ['CN1C=NC2=C1C(=O)N(C)C(=O)N2C[X20]',
#  'C1=NC2=C(N1C[Z7])[X](=O)N(C(=O)N2C[X2])[X8]([H])([H])[H]',
#  'C1=NC2=C(C(=O)N(C[Y1])C(=O)N2[R7e]([H])([H])[H])N1[Y4]([H])([H])[H]',
#  'CN1C=NC2=C1C(=O)N(C)C(=O)N2C[X12]',
#  'CN1C2=C(N(C=N2)[R]([H])([H])[H])[R13d](=O)N(C[X9])C1=O',
#  'CN1C(=O)C2=C(N=[Y2c]([H])N2C[X8c])N(C1=O)[Z13]([H])([H])[H]',
#  'CN1C2=C(C(=O)N(C)C1=O)N(C=N2)[X11]([H])([H])[H]',
#  'CN1C=NC2=C1C(=O)N(C[R18])[X2](=O)N2C([Z15])[R16]',
#  'CN1C=NC2=C1[Y14](=O)N(C)C(=O)N2C[X18b]',
#  'CN1C2=C(N(C=N2)[R12c]([H])([H])[H])[R2](=O)N(C1=O)[Z]([H])([H])[H]',
#  'CN1C=NC2=C1C(=O)N(C[Z])C(=O)N2C[X10e]',
#  'CN1C=NC2=C1[Z2b](=O)N(C)[X](=O)N2C',
#  'CN1C=NC2=C1C(=O)N(C[X7])C(=O)N2C',
#  'CN1C2=C(C(=O)N(C)C1=O)N(C=N2)C[Z9]',
#  'CN1C2=C(C(=O)N(C)C1=O)N(C)[R17]([H])=N2',
#  'CN1C2=C(C(=O)N(C1=O)[X]([H])([H])[H])N(C=N2)C[X4d]',
#  'CN1C=NC2=C1[Y18](=O)N(C)C(=O)N2C[Y20]',
#  'CN1C2=C(N=C1[X8b])N(C(=O)N(C)C2=O)C([X])[R2]',
#  'CN1C2=C(C(=O)N(C[R11f])C1=O)N(C=N2)[R5]([H])([Z])[Z]',
#  'CN1C2=C(C(=O)N(C)C1=O)N(C=N2)[Z12c]([H])([H])[Z2]',
#  'C(N1C2=C(N=C1[R14])N(C[X])C(=O)N(C2=O)[Z14]([H])([H])[H])[Y]',
#  'CN1C2=C(C(=O)N(C1=O)[Y18]([H])([H])[Y20])N(C[X])C(=N2)[Z17d]',
#  'CN1[Y18](=O)C2=C(N=CN2C[X4c])N(C[R15a])[Y19c]1=O',
#  'CN1C=NC2=C1C(=O)N(C[Y2])C(=O)N2C',
#  'CN1C2=C(C(=O)N(C)C1=O)N(C=N2)C[Z20]',
#  'CN1C=NC2=C1C(=O)N(C[Y])[X20b](=O)N2[R9]([H])([H])[Y16d]',
#  'CN1C2=C(N=C1[X16])N(C)C(=O)N(C)C2=O',
#  'CN1C=NC2=C1C(=O)N(C[R1])C(=O)N2C',
#  'CN1C=NC2=C1C(=O)N(C[Z1a])C(=O)N2C([R5])[Y5d]',
#  'CN1C=NC2=C1[Y10](=O)N(C)C(=O)N2C',
#  'CN1C2=C(N=[X1a]1[H])N(C[X1])C(=O)N(C[Z1])C2=O',
#  'CN1C=NC2=C1[Y10](=O)N(C)C(=O)N2C',
#  'CN1C(=O)C2=C(N=CN2C([R])[Y10])N(C1=O)C([Y11])[R20f]',
#  'CN1C2=C(N(C=N2)C([Z3])[Z4f])[Z6b](=O)N(C)C1=O',
#  'CN1C2=C(N=[Z]1[H])N(C[Y9a])C(=O)N(C[R8])C2=O',
#  'CN1C2=C(N(C=N2)[Y9]([H])([H])[H])[Y12b](=O)N(C)C1=O',
#  'CN1C=NC2=C1C(=O)N(C[Z1])C(=O)N2C[Z]',
#  'CN1C=NC2=C1C(=O)N(C[Y11b])[R](=O)N2[X]([H])([H])[H]',
#  'CN1C2=C(N=C1[R17])N(C(=O)N(C[Z10])C2=O)[Y13a]([H])([H])[Z20]',
#  'CN1C=NC2=C1C(=O)N(C[Y13])C(=O)N2[X1]([H])([H])[H]',
#  'CN1C(=O)N(C[Y12f])C2=C(N(C(=N2)[Y9])[Y13]([H])([H])[H])[R17b]1=O',
#  'CN1C2=C(N(C[X18])[X2]([H])=N2)[R14](=O)N(C)C1=O',
#  'CN1C(=O)C2=C(N=CN2[X19d]([H])([H])[H])N(C1=O)[X14]([H])([H])[H]',
#  'CN1C=NC2=C1C(=O)N(C[R])C(=O)N2C',
#  'CN1C(=O)C2=C(N=CN2C[Z11b])N(C1=O)[R6c]([H])([H])[H]',
#  'CN1C2=C(C(=O)N(C[Z4c])[X2]1=O)N([R18]([H])([H])[H])[Y19]([H])=N2',
#  'CN1C=NC2=C1C(=O)N(C)C(=O)N2C[Y]',
#  'CN1C(=O)C2=C(N=CN2C[X16e])N(C1=O)[Z15]([H])([H])[H]',
#  'CN1C=NC2=C1C(=O)N(C)C(=O)N2C[R5]',
#  'CN1C2=C(N=[Y7]1[H])N(C[X9])[X4f](=O)N(C)[X14]2=O',
#  'CN1[R](=O)C2=C(N=CN2C[R])N([Z1]([H])([H])[H])[Z]1=O',
#  'CN1C=NC2=C1[R19d](=O)N(C[Y])C(=O)N2C',
#  'CN1C2=C(C(=O)N(C[Z8])C1=O)N(C)[X17]([H])=N2',
#  'CN1C(=O)C2=C(N=CN2[Y1]([H])([H])[X16f])N(C[X17])C1=O',
#  'CN1C2=C(C(=O)N(C)C1=O)N(C[X20])C(=N2)[Y12f]',
#  'CN1C=NC2=C1C(=O)N(C[Y4b])[Z](=O)N2C[Y]',
#  'C1=NC2=C(C(=O)N(C(=O)N2C[Z5])C([Z])[Z])N1C[X15c]',
#  'CN1C2=C(N=C1[Z2e])N(C)C(=O)N(C2=O)[X4b]([H])([H])[H]',
#  'CN1C(=O)C2=C(N=[Z13]([H])N2C)N(C[Z])C1=O',
#  'CN1C(=O)C2=C(N=CN2C[Z10])N(C1=O)[Y16]([H])([H])[H]',
#  'CN1C(=O)C2=C(N=CN2C[X17])N(C1=O)[R18]([H])([X])[X6]',
#  'CN1C2=C(C(=O)N(C)C1=O)N(C=N2)C[R17]',
#  'CN1C2=C(N=C1[Z6])N(C)[Z17c](=O)N(C[R4])C2=O',
#  'C(N1C2=C(C(=O)N(C[R1])C1=O)N(C(=N2)[R13])[Z3f]([H])([H])[H])[X19f]',
#  'CN1C2=C(C(=O)N(C[Y])C1=O)N(C=N2)[Y4a]([H])([H])[H]',
#  'CN1C(=O)C2=C(N=CN2C[Y4b])N(C[R14])C1=O',
#  'C1=NC2=C(C(=O)N(C[Z14])C(=O)N2C[Z16])N1C[R20]',
#  'C1=NC2=C(C(=O)N(C(=O)N2C[Y20])C([Z17d])[Y13])N1[X8]([H])([H])[H]',
#  'CN1C=NC2=C1C(=O)N(C(=O)N2C)[Y9]([H])([H])[R20]',
#  'CN1C2=C(C(=O)N(C1=O)C([Y16f])[X14e])N(C=N2)[Y4]([H])([H])[X17f]',
#  'CN1C=NC2=C1C(=O)N(C(=O)N2C)[X19e]([H])([H])[H]',
#  'CN1C=NC2=C1C(=O)N(C(=O)N2[X15]([H])([H])[H])[X5]([H])([H])[H]',
#  'CN1C2=C(C(=O)N(C)[Z18]1=O)N([X13]([H])([H])[H])[Y8]([H])=N2',
#  'CN1C2=C(N(C=N2)C[R19])[Y11](=O)N(C[Y3])C1=O',
#  'CN1C2=C(N(C=N2)[Z11]([H])([H])[H])[R](=O)N(C)C1=O',
#  'CN1C=NC2=C1C(=O)N(C)C(=O)N2C([Z18e])[R19]',
#  'C1=NC2=C(C(=O)N(C[R])C(=O)N2C[Z])N1C[Z14]',
#  'CN1C2=C(C(=O)N(C)C1=O)N(C[Z3])C(=N2)[X]',
#  'CN1C=NC2=C1C(=O)N(C(=O)N2C)[R10]([H])([H])[H]',
#  'CN1C2=C(C(=O)N(C1=O)[X]([H])([H])[H])N(C=N2)C[R7a]',
#  'CN1C2=C(C(=O)N(C)C1=O)N(C=N2)C[Y19]',
#  'CN1C2=C(C(=O)N(C1=O)[X]([H])([H])[H])N(C[Z12a])[Y11]([H])=N2',
#  'CN1C2=C(N=[Z]1[H])N(C)[R16](=O)N(C)C2=O',
#  'CN1C=NC2=C1C(=O)N(C)[Z12](=O)N2C',
#  'CN1C2=C(C(=O)N(C)C1=O)N(C)[Z8e]([H])=N2',
#  'CN1C(=O)C2=C(N=CN2C[Y9])N(C1=O)[Z]([H])([H])[H]',
#  'CN1C2=C(N(C)C(=N2)[X5])[R](=O)N(C[R17])C1=O',
#  'CN1C2=C(C(=O)N(C)[R11]1=O)N(C(=N2)[Z13d])C([X18])[R]',
#  'C1=NC2=C(C(=O)N(C[X6])C(=O)N2[X19]([H])([H])[H])N1C[R1d]',
#  'C1=NC2=C(C(=O)N(C[R])[Y5](=O)N2C[R])N1C[Y13]',
#  'CN1C2=C(C(=O)N(C1=O)C([X6])([R14a])[Y4])N(C=N2)C[Z4]',
#  'C1=NC2=C(C(=O)N(C[X15c])C(=O)N2C([X4])[R1])N1C[Z17e]',
#  'CN1C2=C(N(C[Y3])[Y]([H])=N2)[Y18](=O)N(C)C1=O',
#  'CN1C(=O)C2=C(N=C(N2[R9]([H])([H])[Y11])[X8a])N(C[Z])C1=O',
#  'CN1C2=C(C(=O)N(C)C1=O)N(C=N2)C[R20c]',
#  'CN1C=NC2=C1C(=O)N(C[Z8])C(=O)N2C[Z3b]',
#  'CN1C=NC2=C1C(=O)N(C(=O)N2C)[Z14b]([H])([H])[H]',
#  'CN1C=NC2=C1C(=O)N(C[X16])C(=O)N2C',
#  'CN1C=NC2=C1C(=O)N(C(=O)N2C)[X8]([H])([H])[H]',
#  'CN1C2=C(N(C(=N2)[Y20])[R2e]([H])([H])[H])[R12](=O)N(C1=O)[Y12b]([H])([H])[H]']

# %% [markdown]
# Depict the markush structures using RanDepict

# %%
with RandomDepictor() as depictor:
    markush_depictions = [depictor.random_depiction(smi, shape=(100,100))
                          for smi in markush_smiles]
ipyplot.plot_images(markush_depictions, max_images=100, img_width=100)
# Out:
# [16:41:34] WARNING: not removing hydrogen atom with dummy atom neighbors
# [16:41:34] WARNING: not removing hydrogen atom with dummy atom neighbors
# [16:41:34] WARNING: not removing hydrogen atom with dummy atom neighbors
# [16:41:34] WARNING: not removing hydrogen atom with dummy atom neighbors
# Warning! Rogue electron.
# R18_10
# Warning! Rogue electron.
# Z15_15
# Warning! Rogue electron.
# R16_16
# Warning! Rogue electron.
# R18_10
# Warning! Rogue electron.
# Z15_15
# Warning! Rogue electron.
# R16_16
# Warning! Rogue electron.
# Z9_14
# Warning! Rogue electron.
# Z9_14
# Warning! Rogue electron.
# Z20_14
# Warning! Rogue electron.
# Z20_14
# Warning! Rogue electron.
# R1_10
# Warning! Rogue electron.
# R1_10
# Warning! Rogue electron.
# Z1_10
# Warning! Rogue electron.
# Z_15
# Warning! Rogue electron.
# Z1_10
# Warning! Rogue electron.
# Z_15
# [16:41:38] WARNING: not removing hydrogen atom with dummy atom neighbors
# [16:41:38] WARNING: not removing hydrogen atom with dummy atom neighbors
# [16:41:38] WARNING: not removing hydrogen atom with dummy atom neighbors
# [16:41:38] WARNING: not removing hydrogen atom with dummy atom neighbors
# [16:41:38] WARNING: not removing hydrogen atom with dummy atom neighbors
# [16:41:38] WARNING: not removing hydrogen atom with dummy atom neighbors
# [16:41:39] WARNING: not removing hydrogen atom with dummy atom neighbors
# [16:41:39] WARNING: not removing hydrogen atom with dummy atom neighbors
# [16:41:39] WARNING: not removing hydrogen atom with dummy atom neighbors
# [16:41:39] WARNING: not removing hydrogen atom with dummy atom neighbors
#     <style>
#         #ipyplot-html-viewer-toggle-kPmwkFMeKgNKnJi7FR8H5A {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-kPmwkFMeKgNKnJi7FR8H5A {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-kPmwkFMeKgNKnJi7FR8H5A {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-kPmwkFMeKgNKnJi7FR8H5A:checked ~ #ipyplot-html-viewer-textarea-kPmwkFMeKgNKnJi7FR8H5A {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-kPmwkFMeKgNKnJi7FR8H5A:checked + #ipyplot-html-viewer-label-kPmwkFMeKgNKnJi7FR8H5A:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-kPmwkFMeKgNKnJi7FR8H5A">
#         <label id="ipyplot-html-viewer-label-kPmwkFMeKgNKnJi7FR8H5A" for="ipyplot-html-viewer-toggle-kPmwkFMeKgNKnJi7FR8H5A">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-kPmwkFMeKgNKnJi7FR8H5A" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-chy92SzLmTHxnjT44pf52m {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-chy92SzLmTHxnjT44pf52m {
#             width: 100px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-chy92SzLmTHxnjT44pf52m {
#             width: 100px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-chy92SzLmTHxnjT44pf52m span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-chy92SzLmTHxnjT44pf52m span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-chy92SzLmTHxnjT44pf52m img {
#             width: 100px;
#         }
#
#         div.ipyplot-content-div-chy92SzLmTHxnjT44pf52m span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-chy92SzLmTHxnjT44pf52m span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-chy92SzLmTHxnjT44pf52m]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-chy92SzLmTHxnjT44pf52m]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-chy92SzLmTHxnjT44pf52m]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-chy92SzLmTHxnjT44pf52m">
#     <div class="ipyplot-placeholder-div-chy92SzLmTHxnjT44pf52m">
#         <div id="ipyplot-content-div-chy92SzLmTHxnjT44pf52m-UuEMZyo9kwEmPzmK3iZdir" class="ipyplot-content-div-chy92SzLmTHxnjT44pf52m">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-chy92SzLmTHxnjT44pf52m-UuEMZyo9kwEmPzmK3iZdir">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-chy92SzLmTHxnjT44pf52m">
#         <div id="ipyplot-content-div-chy92SzLmTHxnjT44pf52m-DUcGEmqDa79L4tSoUpqiB6" class="ipyplot-content-div-chy92SzLmTHxnjT44pf52m">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-chy92SzLmTHxnjT44pf52m-DUcGEmqDa79L4tSoUpqiB6">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-chy92SzLmTHxnjT44pf52m">
#         <div id="ipyplot-content-div-chy92SzLmTHxnjT44pf52m-cCCACNTEWUYVbqmQpf5H3N" class="ipyplot-content-div-chy92SzLmTHxnjT44pf52m">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-chy92SzLmTHxnjT44pf52m-cCCACNTEWUYVbqmQpf5H3N">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-chy92SzLmTHxnjT44pf52m">
#         <div id="ipyplot-content-div-chy92SzLmTHxnjT44pf52m-cZCL76AoupJ9cp6JY6Nbh8" class="ipyplot-content-div-chy92SzLmTHxnjT44pf52m">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-chy92SzLmTHxnjT44pf52m-cZCL76AoupJ9cp6JY6Nbh8">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-chy92SzLmTHxnjT44pf52m">
#         <div id="ipyplot-content-div-chy92SzLmTHxnjT44pf52m-KjZr4zUXXLBWKfzTdwXiHT" class="ipyplot-content-div-chy92SzLmTHxnjT44pf52m">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-chy92SzLmTHxnjT44pf52m-KjZr4zUXXLBWKfzTdwXiHT">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-chy92SzLmTHxnjT44pf52m">
#         <div id="ipyplot-content-div-chy92SzLmTHxnjT44pf52m-idfg2Le8qtMVxP5T3btic9" class="ipyplot-content-div-chy92SzLmTHxnjT44pf52m">
#             <h4 style="font-size: 12px; word-wrap: break-word;">5</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-chy92SzLmTHxnjT44pf52m-idfg2Le8qtMVxP5T3btic9">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-chy92SzLmTHxnjT44pf52m">
#         <div id="ipyplot-content-div-chy92SzLmTHxnjT44pf52m-QCaYzLJDmcBF3naTqX2cjB" class="ipyplot-content-div-chy92SzLmTHxnjT44pf52m">
#             <h4 style="font-size: 12px; word-wrap: break-word;">6</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-chy92SzLmTHxnjT44pf52m-QCaYzLJDmcBF3naTqX2cjB">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-chy92SzLmTHxnjT44pf52m">
#         <div id="ipyplot-content-div-chy92SzLmTHxnjT44pf52m-hKK6ZqkC9UMvxNkJZ3tvV
#         <style>
#         #ipyplot-imgs-container-div-chy92SzLmTHxnjT44pf52m {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-chy92SzLmTHxnjT44pf52m {
#             width: 100px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-chy92SzLmTHxnjT44pf52m {
#             width: 100px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-chy92SzLmTHxnjT44pf52m span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-chy92SzLmTHxnjT44pf52m span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-chy92SzLmTHxnjT44pf52m img {
#             width: 100px;
#         }
#
#         div.ipyplot-content-div-chy92SzLmTHxnjT44pf52m span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-chy92SzLmTHxnjT44pf52m span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-chy92SzLmTHxnjT44pf52m]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-chy92SzLmTHxnjT44pf52m]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-chy92SzLmTHxnjT44pf52m]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-chy92SzLmTHxnjT44pf52m">
#     <div class="ipyplot-placeholder-div-chy92SzLmTHxnjT44pf52m">
#         <div id="ipyplot-content-div-chy92SzLmTHxnjT44pf52m-UuEMZyo9kwEmPzmK3iZdir" class="ipyplot-content-div-chy92SzLmTHxnjT44pf52m">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-chy92SzLmTHxnjT44pf52m-UuEMZyo9kwEmPzmK3iZdir">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-chy92SzLmTHxnjT44pf52m">
#         <div id="ipyplot-content-div-chy92SzLmTHxnjT44pf52m-DUcGEmqDa79L4tSoUpqiB6" class="ipyplot-content-div-chy92SzLmTHxnjT44pf52m">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-chy92SzLmTHxnjT44pf52m-DUcGEmqDa79L4tSoUpqiB6">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-chy92SzLmTHxnjT44pf52m">
#         <div id="ipyplot-content-div-chy92SzLmTHxnjT44pf52m-cCCACNTEWUYVbqmQpf5H3N" class="ipyplot-content-div-chy92SzLmTHxnjT44pf52m">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-chy92SzLmTHxnjT44pf52m-cCCACNTEWUYVbqmQpf5H3N">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-chy92SzLmTHxnjT44pf52m">
#         <div id="ipyplot-content-div-chy92SzLmTHxnjT44pf52m-cZCL76AoupJ9cp6JY6Nbh8" class="ipyplot-content-div-chy92SzLmTHxnjT44pf52m">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-chy92SzLmTHxnjT44pf52m-cZCL76AoupJ9cp6JY6Nbh8">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-chy92SzLmTHxnjT44pf52m">
#         <div id="ipyplot-content-div-chy92SzLmTHxnjT44pf52m-KjZr4zUXXLBWKfzTdwXiHT" class="ipyplot-content-div-chy92SzLmTHxnjT44pf52m">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-chy92SzLmTHxnjT44pf52m-KjZr4zUXXLBWKfzTdwXiHT">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-chy92SzLmTHxnjT44pf52m">
#         <div id="ipyplot-content-div-chy92SzLmTHxnjT44pf52m-idfg2Le8qtMVxP5T3btic9" class="ipyplot-content-div-chy92SzLmTHxnjT44pf52m">
#             <h4 style="font-size: 12px; word-wrap: break-word;">5</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-chy92SzLmTHxnjT44pf52m-idfg2Le8qtMVxP5T3btic9">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-chy92SzLmTHxnjT44pf52m">
#         <div id="ipyplot-content-div-chy92SzLmTHxnjT44pf52m-QCaYzLJDmcBF3naTqX2cjB" class="ipyplot-content-div-chy92SzLmTHxnjT44pf52m">
#             <h4 style="font-size: 12px; word-wrap: break-word;">6</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-chy92SzLmTHxnjT44pf52m-QCaYzLJDmcBF3naTqX2cjB">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-chy92SzLmTHxnjT44pf52m">
#         <div id="ipyplot-content-div-chy92SzLmTHxnjT44pf52m-hKK6ZqkC9UMvxNkJZ3tvVn" class="ipyplot-content-div-chy92SzLmTHxnjT44pf52m">
#             <h4 style="font-size: 12px; word-wrap: break-word;">7</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-chy92SzLmTHxnjT44pf52m-hKK6ZqkC9UMvxNkJZ3tvVn">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-chy92SzLmTHxnjT44pf52m">
#         <div id="ipyplot-content-div-chy92SzLmTHxnjT44pf52m-TnmZqzDfacFRsvMENWxCGu" class="ipyplot-content-div-chy92SzLmTHxnjT44pf52m">
#             <h4 style="font-size: 12px; word-wrap: break-word;">8</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-chy92SzLmTHxnjT44pf52m-TnmZqzDfacFRsvMENWxCGu">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-chy92SzLmTHxnjT44pf52m">
#         <div id="ipyplot-content-div-chy92SzLmTHxnjT44pf52m-hZ52o88qPgxvERddaCDgMV" class="ipyplot-content-div-chy92SzLmTHxnjT44pf52m">
#             <h4 style="font-size: 12px; word-wrap: break-word;">9</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-chy92SzLmTHxnjT44pf52m-hZ52o88qPgxvERddaCDgMV">
